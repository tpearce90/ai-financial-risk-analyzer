# %%
import pandas as pd
import matplotlib.pyplot as plt

prices = pd.read_csv(
    "../data/raw/prices.csv",
    index_col=0,
    parse_dates=True
)

returns = prices.pct_change().dropna()

returns.head()
# Out:
#                  GLD       IWM       QQQ       SPY       TLT
# Date
# 2015-01-05  0.015077 -0.013369 -0.014669 -0.018060  0.015709
# 2015-01-06  0.011399 -0.017300 -0.013408 -0.009419  0.018017
# 2015-01-07 -0.005891  0.012315  0.012891  0.012462 -0.001975
# 2015-01-08 -0.004209  0.016962  0.019140  0.017744 -0.013242
# 2015-01-09  0.011385 -0.009603 -0.006583 -0.008013  0.010952

# %%
correlation_matrix = returns.corr()

correlation_matrix
# Out:
#           GLD       IWM       QQQ       SPY       TLT
# GLD  1.000000  0.065313  0.066325  0.056734  0.259915
# IWM  0.065313  1.000000  0.769653  0.866957 -0.155582
# QQQ  0.066325  0.769653  1.000000  0.934256 -0.125108
# SPY  0.056734  0.866957  0.934256  1.000000 -0.177619
# TLT  0.259915 -0.155582 -0.125108 -0.177619  1.000000

# %%
plt.figure(figsize=(8, 6))

plt.imshow(correlation_matrix, cmap="coolwarm")

plt.colorbar()

plt.xticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns,
    rotation=45
)

plt.yticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns
)

plt.title("Asset Correlation Matrix")

plt.show()
